# %%
# Importing the TextPreprocessor class from the module
from OutText_preprocessing.text_preprocessing import TextPreprocessor
import autocorrect 

# Create an instance of the TextPreprocessor class with the required language
preprocessor = TextPreprocessor(language="english")

# Example text to demonstrate the different methods
text = "I'm feeling great today! 😊 It's a sunny day, but I don't know where my keys are. Don't forget to visit us!"

# 1. Clean the text (basic cleaning)
cleaned_text = preprocessor.clean_text(text)
print(f"Cleaned text: {cleaned_text}")

# 2. Advanced clean the text (removes more unwanted elements like emojis, etc.)
advanced_cleaned_text = preprocessor.advanced_clean(text)
print(f"Advanced cleaned text: {advanced_cleaned_text}")



# 4. Remove special characters from the text (keep only alphabets)
text_with_special_chars = "Hello!!! How are you?? @#@"
cleaned_special_text = preprocessor.remove_special_characters(text_with_special_chars)
print(f"Text with special characters removed: {cleaned_special_text}")

# 5. Get the most common words from the text (top 5 words)
common_words = preprocessor.get_most_common_words(text, num_words=5)
print(f"Most common words: {common_words}")

# 6. Preprocess multi-language text (example in Spanish)
text_in_spanish = "no quiero ir"
cleaned_spanish_text = preprocessor.preprocess_multi_language(text_in_spanish, language="spanish")
print(f"Cleaned Spanish text: {cleaned_spanish_text}")

# 7. Apply text cleaning to a DataFrame column
import pandas as pd

# Example DataFrame with a text column
df = pd.DataFrame({'text': ["This is a test.", "Another example here! Let's clean this text."]})

# Apply the clean_text method to the DataFrame's 'text' column
df['cleaned_text'] = preprocessor.apply_to_dataframe(df, 'text', 'clean_text')
print("DataFrame after text cleaning:")
print(df)# Importing the TextPreprocessor class from the module
from OutText_preprocessing.text_preprocessing import TextPreprocessor
import autocorrect 

# Create an instance of the TextPreprocessor class with the required language
preprocessor = TextPreprocessor(language="english")

# Example text to demonstrate the different methods
text = "I'm feeling great today! 😊 It's a sunny day, but I don't know where my keys are. Don't forget to visit us!"

# 1. Clean the text (basic cleaning)
cleaned_text = preprocessor.clean_text(text)
print(f"Cleaned text: {cleaned_text}")

# 2. Advanced clean the text (removes more unwanted elements like emojis, etc.)
advanced_cleaned_text = preprocessor.advanced_clean(text)
print(f"Advanced cleaned text: {advanced_cleaned_text}")

# 3. Correct spelling mistakes in the text
text_with_typos = "I have a speling mistake"

# 4. Remove special characters from the text (keep only alphabets)
text_with_special_chars = "Hello!!! How are you?? @#@"
cleaned_special_text = preprocessor.remove_special_characters(text_with_special_chars)
print(f"Text with special characters removed: {cleaned_special_text}")

# 5. Get the most common words from the text (top 5 words)
common_words = preprocessor.get_most_common_words(text, num_words=5)
print(f"Most common words: {common_words}")

# 6. Preprocess multi-language text (example in Spanish)
text_in_spanish = "no quiero ir"
cleaned_spanish_text = preprocessor.preprocess_multi_language(text_in_spanish, language="spanish")
print(f"Cleaned Spanish text: {cleaned_spanish_text}")

# 7. Apply text cleaning to a DataFrame column
import pandas as pd

# Example DataFrame with a text column
df = pd.DataFrame({'text': ["This is a test.", "Another example here! Let's clean this text."]})

# Apply the clean_text method to the DataFrame's 'text' column
df['cleaned_text'] = preprocessor.apply_to_dataframe(df, 'text', 'clean_text')
print("DataFrame after text cleaning:")
print(df)
# Out:
# Cleaned text: im feeling great today  sunny day dont know keys dont forget visit us
# Advanced cleaned text: feeling great today  sunny day dont know keys dont forget visit
# Text with special characters removed: Hello How are you
# Most common words: [("I'm", 1), ('feeling', 1), ('great', 1), ('today!', 1), ('😊', 1)]
# Cleaned Spanish text: quiero ir
# DataFrame after text cleaning:
#                               text                     cleaned_text
# 0                             test                             test
# 1  another example lets clean text  another example lets clean text
# Cleaned text: im feeling great today  sunny day dont know keys dont forget visit us
# Advanced cleaned text: feeling great today  sunny day dont know keys dont forget visit
# Text with special characters removed: Hello How are you
# Most common words: [("I'm", 1), ('feeling', 1), ('great', 1), ('today!', 1), ('😊', 1)]
# Cleaned Spanish text: quiero ir
# DataFrame after text cleaning:
# ...
